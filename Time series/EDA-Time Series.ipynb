# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# Install Pandas Data reader
import pandas_datareader as pdr
from datetime import datetime

# %%
pdr.get_data_stooq(['TSLA'])
# Out:
# Attributes     Close      High       Low      Open     Volume
# Symbols         TSLA      TSLA      TSLA      TSLA       TSLA
# Date
# 2024-02-16  199.9500  203.1700  197.4000  202.0600  111346705
# 2024-02-15  200.4500  200.8800  188.8595  189.1600  120831762
# 2024-02-14  188.7100  188.8900  183.3500  185.3000   81202987
# 2024-02-13  184.0200  187.2600  182.1087  183.9900   86759478
# 2024-02-12  188.1300  194.7300  187.2800  192.1100   95498597
# ...              ...       ...       ...       ...        ...
# 2019-02-25   19.9180   20.1937   19.8000   19.8607   99397830
# 2019-02-22   19.6473   19.7667   19.4733   19.6327   86108370
# 2019-02-21   19.4153   20.2160   19.3667   20.1207  133637730
# 2019-02-20   20.1707   20.4200   19.9333   20.2940  107131755
# 2019-02-19   20.3760   20.7697   20.3647   20.4373   62526645
#
# [1259 rows x 5 columns]

# %%
df
# Out:
# Attributes     Close      High       Low      Open     Volume
# Date
# 2024-02-16  199.9500  203.1700  197.4000  202.0600  111346705
# 2024-02-15  200.4500  200.8800  188.8595  189.1600  120831762
# 2024-02-14  188.7100  188.8900  183.3500  185.3000   81202987
# 2024-02-13  184.0200  187.2600  182.1087  183.9900   86759478
# 2024-02-12  188.1300  194.7300  187.2800  192.1100   95498597
# ...              ...       ...       ...       ...        ...
# 2019-02-25   19.9180   20.1937   19.8000   19.8607   99397830
# 2019-02-22   19.6473   19.7667   19.4733   19.6327   86108370
# 2019-02-21   19.4153   20.2160   19.3667   20.1207  133637730
# 2019-02-20   20.1707   20.4200   19.9333   20.2940  107131755
# 2019-02-19   20.3760   20.7697   20.3647   20.4373   62526645
#
# [1259 rows x 5 columns]

# %%
df = pdr.get_data_stooq(['TSLA'])
df.columns = df.columns.droplevel(level=[1])
df.columns.name=None
df.head()
# Out:
#              Close    High       Low    Open     Volume
# Date
# 2024-02-16  199.95  203.17  197.4000  202.06  111346705
# 2024-02-15  200.45  200.88  188.8595  189.16  120831762
# 2024-02-14  188.71  188.89  183.3500  185.30   81202987
# 2024-02-13  184.02  187.26  182.1087  183.99   86759478
# 2024-02-12  188.13  194.73  187.2800  192.11   95498597

# %%
df['High'].plot(figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df.index = pd.to_datetime(df.index,format=('%Y-%m-%d'))

# %%
df['High'].plot(ylim=(0,450),figsize=(12,4))
# Out:
# <Axes: xlabel='Date'>

# %%
df['High'].plot(ylim=(0,450),figsize=(12,4),color='green',ls='--')
# Out:
# <Axes: xlabel='Date'>

# %%
df['2020']
# Out:
#                Close      High       Low      Open     Volume
# Date
# 2020-12-31  235.2230  239.5730  230.3730  233.3300  148949784
# 2020-12-30  231.5930  232.2000  222.7870  224.0000  128538063
# 2020-12-29  221.9970  223.3000  218.3330  220.3330   68732433
# 2020-12-28  221.2300  227.1330  220.2670  224.8370   96835683
# 2020-12-24  220.5900  222.0300  213.6670  214.3300   68596704
# ...              ...       ...       ...       ...        ...
# 2020-01-08   32.8093   33.2333   31.2153   31.5800  467990895
# 2020-01-07   31.2707   31.4420   30.2237   30.7600  273137070
# 2020-01-06   30.1027   30.1040   29.3333   29.3647  152362485
# 2020-01-03   29.5340   30.2667   29.1280   29.3667  266920455
# 2020-01-02   28.6840   28.7130   28.1140   28.3000  143375790
#
# [253 rows x 5 columns]

# %%
index = df.loc['2020-01':'2022-01'].index
share_open = df.loc['2020-01':'2022-01']['Open']

# %%
figure,axis = plt.subplots()
plt.tight_layout()
plt.xticks(rotation=45)
axis.plot(index,share_open)

# %%
# Date time index

# %%
df = df.reset_index()

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df = df.set_index('Date',drop=True)

# %%
df
# Out:
#                Close      High       Low      Open     Volume
# Date
# 2024-02-16  199.9500  203.1700  197.4000  202.0600  111346705
# 2024-02-15  200.4500  200.8800  188.8595  189.1600  120831762
# 2024-02-14  188.7100  188.8900  183.3500  185.3000   81202987
# 2024-02-13  184.0200  187.2600  182.1087  183.9900   86759478
# 2024-02-12  188.1300  194.7300  187.2800  192.1100   95498597
# ...              ...       ...       ...       ...        ...
# 2019-02-25   19.9180   20.1937   19.8000   19.8607   99397830
# 2019-02-22   19.6473   19.7667   19.4733   19.6327   86108370
# 2019-02-21   19.4153   20.2160   19.3667   20.1207  133637730
# 2019-02-20   20.1707   20.4200   19.9333   20.2940  107131755
# 2019-02-19   20.3760   20.7697   20.3647   20.4373   62526645
#
# [1259 rows x 5 columns]

# %%
date = datetime(2021,11,21)

# %%
datetime.now()
# Out:
# datetime.datetime(2024, 2, 18, 21, 4, 49, 703405)

# %%
date.day
# Out:
# 21

# %%
date.date()
# Out:
# datetime.date(2021, 11, 21)

# %%
date.isocalendar()
# Out:
# datetime.IsoCalendarDate(year=2021, week=46, weekday=7)

# %%
# Resampling technique
df.resample(rule='A').min() # minimum values for the specific year
# Out:
#                Close      High       Low      Open    Volume
# Date
# 2019-12-31   11.9313   12.4453   11.7993   12.0733  36984435
# 2020-12-31   24.0813   26.9907   23.3673   24.9797  52073166
# 2021-12-31  187.6670  188.7370  179.8300  184.1830  29401674
# 2022-12-31  109.1000  116.2700  108.2400  110.3500  41864742
# 2023-12-31  108.1000  111.7500  101.8100  103.0000  65125203
# 2024-12-31  181.0600  184.6800  175.0100  177.2100  81202987

# %%
df.resample(rule='A').max() # minimum values for the specific year
# Out:
#                Close      High       Low     Open     Volume
# Date
# 2019-12-31   28.7293   29.0207   28.4233   29.000  450091365
# 2020-12-31  235.2230  239.5730  230.3730  233.330  914081370
# 2021-12-31  409.9700  414.4970  405.6670  411.470  268189377
# 2022-12-31  399.9270  402.6670  378.6800  396.517  221923313
# 2023-12-31  293.3400  299.2900  289.5201  296.040  306590613
# 2024-12-31  248.4200  251.2500  244.4100  250.080  198076787

# %%
df.resample(rule='A').max()['Open'].plot(legend=True,label='Maximum Open value')
df.resample(rule='A').min()['Open'].plot(legend=True,label='Minimum Open value')
plt.title('Yearly Max vs Min Open')
# Out:
# Text(0.5, 1.0, 'Yearly Max vs Min Open')

# %%
df.resample(rule='QS').max()['Open'].plot(legend=True,label='Maximum Open value')
df.resample(rule='QS').min()['Open'].plot(legend=True,label='Minimum Open value')
plt.title('Quarterly Max vs Min Open')
# Out:
# Text(0.5, 1.0, 'Quarterly Max vs Min Open')

# %%
df.resample(rule='M').max()['Open'].plot(legend=True,label='Maximum Open value')
df.resample(rule='M').min()['Open'].plot(legend=True,label='Minimum Open value')
plt.title('Monthly Max vs Min Open')
# Out:
# Text(0.5, 1.0, 'Monthly Max vs Min Open')

# %%
df.resample(rule='M').median()['Low'].plot(legend=True,label='Average Low value')
df.resample(rule='M').median()['High'].plot(legend=True,label='Average High value')
plt.title('Monthly Average Open')
# Out:
# Text(0.5, 1.0, 'Monthly Average Open')

# %%
df.resample(rule='M').mean()['Low'].plot(legend=True,label='Average Low value')
df.resample(rule='M').mean()['High'].plot(legend=True,label='Average High value')
plt.title('Monthly Average Open')
# Out:
# Text(0.5, 1.0, 'Monthly Average Open')

# %%
df['High'].rolling(10).mean().dropna().plot()
df['High'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df['Open'].rolling(31).mean().dropna().plot(legend=True,label='Rolling')
df['Open'].plot(legend=True,label='Open')
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# 1. Read the microsoft data
# 2. Get the maximum price of the year 2017 to 2022
# 3. Which is the date of the highest price of the stock
# 4. Which is the date of the lowest price of the stock

# %%
df_msft = pdr.get_data_stooq('MSFT')

# %%
filt = (df['Close']==df['Close'].max())
df[filt]
# Out:
#              Close     High      Low    Open    Volume
# Date
# 2021-11-04  409.97  414.497  405.667  411.47  76192230

# %%
filt = (df['Close']==df['Close'].min())
df[filt]
# Out:
#               Close     High      Low     Open     Volume
# Date
# 2019-06-03  11.9313  12.4453  11.7993  12.3673  195966150

# %%
df.resample(rule='A').max()[['Close','Open']]['2017':'2022']
# Out:
#                Close     Open
# Date
# 2019-12-31   28.7293   29.000
# 2020-12-31  235.2230  233.330
# 2021-12-31  409.9700  411.470
# 2022-12-31  399.9270  396.517

# %%
df['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
train = df['Close'].resample(rule='M').median().iloc[:50].reset_index()
test = df['Close'].resample(rule='M').median().iloc[50:].reset_index()

# %%
train = train.set_index('Date')
test = test.set_index('Date')

# %%
test
# Out:
#               Close
# Date
# 2023-04-30  184.310
# 2023-05-31  171.935
# 2023-06-30  255.900
# 2023-07-31  270.890
# 2023-08-31  242.190
# 2023-09-30  253.810
# 2023-10-31  248.825
# 2023-11-30  234.210
# 2023-12-31  247.810
# 2024-01-31  215.550
# 2024-02-29  188.420

# %%
historical_mean = np.mean(train)

# %%
historical_mean
# Out:
# 162.72835600000002

# %%
test.loc[:,'pred_mean'] = historical_mean

# %%
test.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def mape(y_true,y_pred):
    return np.mean(np.abs((y_true-y_pred)/y_true)*100)

# %%
mape(test['Close'],test['pred_mean'])
# Out:
# 27.24482137364888

# %%
import matplotlib.pyplot as plt
fig, ax =plt.subplots()
ax.plot(train['Close'],'g-',label='Train')
ax.plot(test['Close'],'b-',label='Test')
ax.plot(test['pred_mean'],'r--',label='Predicted (mean)')
ax.set_xlabel('Date')
ax.legend(loc='best')
ax.set_ylabel('Closing price')
ax.set_title('Closing price of stocks')
# Out:
# Text(0.5, 1.0, 'Closing price of stocks')

# %%
test.loc[:,"pred_last_season"] = train['Close'][-11:].values

# %%
test
# Out:
#               Close   pred_mean  pred_last_season
# Date
# 2023-04-30  184.310  162.728356          252.7530
# 2023-05-31  171.935  162.728356          235.0700
# 2023-06-30  255.900  162.728356          245.0365
# 2023-07-31  270.890  162.728356          296.4530
# 2023-08-31  242.190  162.728356          288.5900
# 2023-09-30  253.810  162.728356          222.4150
# 2023-10-31  248.825  162.728356          190.7200
# 2023-11-30  234.210  162.728356          156.8000
# 2023-12-31  247.810  162.728356          127.9750
# 2024-01-31  215.550  162.728356          200.8600
# 2024-02-29  188.420  162.728356          190.4100

# %%
mape_seasonal = mape(test['pred_last_season'],test['Close'])

# %%
mape_seasonal
# Out:
# 25.365437523401628

# %%
import matplotlib.pyplot as plt
fig, ax =plt.subplots()
ax.plot(train['Close'],'g-',label='Train')
ax.plot(test['Close'],'b-',label='Test')
ax.plot(test['pred_mean'],'r--',label='Predicted (mean)')
ax.plot(test['pred_last_season'],'g--',label='Predicted (Seasonal)')
ax.set_xlabel('Date')
ax.legend(loc='best')
ax.set_ylabel('Closing price')
ax.set_title('Closing price of stocks')
# Out:
# Text(0.5, 1.0, 'Closing price of stocks')

# %%
np.random.seed(42)
steps = np.random.standard_normal(1000)
steps[0]=0
random_walk = np.cumsum(steps)

# %%
fig, ax = plt.subplots()
ax.plot(random_walk)
ax.set_xlabel('TimeStep')
ax.set_ylabel('Value')
ax.set_title(('Random Walk'))
plt.tight_layout()

# %%
random_walk
# Out:
# array([  0.        ,  -0.1382643 ,   0.50942424,   2.03245409,
#          1.79830072,   1.56416376,   3.14337658,   3.91081131,
#          3.44133692,   3.98389696,   3.52047927,   3.05474952,
#          3.29671179,   1.38343154,  -0.34148629,  -0.90377382,
#         -1.91660494,  -1.6023576 ,  -2.51038168,  -3.92268538,
#         -2.45703661,  -2.68281291,  -2.61528471,  -4.04003289,
#         -4.58441562,  -4.47349303,  -5.62448661,  -5.24878859,
#         -5.84942728,  -6.14112103,  -6.74282764,  -4.89054946,
#         -4.90404668,  -5.96175761,  -5.1392127 ,  -6.36005635,
#         -6.15119275,  -8.11086288,  -9.43904893,  -9.24218769,
#         -8.50372111,  -8.33235283,  -8.44800111,  -8.74910481,
#        -10.2276268 , -10.94747101, -11.40810978, -10.35098755,
#        -10.00736926, -11.77040942, -11.44632545, -11.83140773,
#        -12.50832973, -11.89665344, -10.86565392,  -9.9343738 ,
#        -10.77359132, -11.0828037 , -10.75154026,  -9.77599514,
# ...

# %%
from statsmodels.tsa.stattools import adfuller
ADF_result = adfuller(random_walk)
print(f'ADF Statistic: {ADF_result[0]}')
print(f'p-value: {ADF_result[1]}')
# Out:
# ADF Statistic: -0.9659524876918755
# p-value: 0.7654789696692579

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(random_walk,lags=20)
plt.show()

# %%
diff_random_walk = np.diff(random_walk,n=1)

# %%
from statsmodels.tsa.stattools import adfuller
ADF_result = adfuller(diff_random_walk)
print(f'ADF Statistic: {ADF_result[0]}')
print(f'p-value: {ADF_result[1]}')
# Out:
# ADF Statistic: -31.789310857560594
# p-value: 0.0

# %%
plot_acf(diff_random_walk,lags=20)
plt.show()

# %%
df['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
adfuller_test = adfuller(df['Close'])
print(f'ADF Statistic: {adfuller_test[0]}')
print(f'p-value: {adfuller_test[1]}')
# Out:
# ADF Statistic: -1.1570502775059057
# p-value: 0.6917935304669448

# %%
df['difference_1'] = df['Close'].diff()

# %%
adfuller_test = adfuller(df['difference_1'].dropna())
print(f'ADF Statistic: {adfuller_test[0]}')
print(f'p-value: {adfuller_test[1]}')
# Out:
# ADF Statistic: -6.7290891365288825
# p-value: 3.331235230965678e-09

# %%
import matplotlib.pyplot as plt
fig, ax =plt.subplots()
ax.plot(df['difference_1'].dropna(),'r--',label='1st Difference')
ax.set_xlabel('Date')
ax.legend(loc='best')
ax.set_ylabel('Closing price')
ax.set_title('Closing price of stocks')
# Out:
# Text(0.5, 1.0, 'Closing price of stocks')

# %%
plot_acf(df['Close'],lags=20)
plt.show()

# %%
plot_acf(df['difference_1'].dropna(),lags=20)
plt.show()

# %%
random_walk = pd.DataFrame({'value':random_walk})
random_walk
# Out:
#          value
# 0     0.000000
# 1    -0.138264
# 2     0.509424
# 3     2.032454
# 4     1.798301
# ..         ...
# 995  16.395408
# 996  18.193095
# 997  18.833938
# 998  18.262759
# 999  18.835342
#
# [1000 rows x 1 columns]

# %%
train = random_walk[:800]
test = random_walk[800:]

# %%
test['pred_mead'] = np.mean(train['value'])

# %%
test['last'] = train.iloc[-1].value

# %%
test
# Out:
#          value  pred_mead      last
# 800  -5.876664  -3.677206 -6.814947
# 801  -6.392708  -3.677206 -6.814947
# 802  -6.296588  -3.677206 -6.814947
# 803  -6.758863  -3.677206 -6.814947
# 804  -7.193359  -3.677206 -6.814947
# ..         ...        ...       ...
# 995  16.395408  -3.677206 -6.814947
# 996  18.193095  -3.677206 -6.814947
# 997  18.833938  -3.677206 -6.814947
# 998  18.262759  -3.677206 -6.814947
# 999  18.835342  -3.677206 -6.814947
#
# [200 rows x 3 columns]

# %%
df = pd.read_csv(r"C:\Users\91866\Downloads\widget_sales.csv")

# %%
date_range = pd.date_range('20190101',periods=500)

# %%
df['Date'] = date_range
df.set_index('Date',inplace=True)

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
from statsmodels.tsa.stattools import adfuller
adfuller_test = adfuller(df['widget_sales'])
print(f'ADF Statistic: {adfuller_test[0]}')
print(f'p-value: {adfuller_test[1]}')
# Out:
# ADF Statistic: -1.5121662069359045
# p-value: 0.5274845352272606

# %%
widget_sales_diff = np.diff(df['widget_sales'],n=1)

# %%
plt.plot(widget_sales_diff)

# %%
adfuller_test = adfuller(widget_sales_diff)
print(f'ADF statistic: {adfuller_test[0]}')
print(f'p-value: {adfuller_test[1]}')
# Out:
# ADF statistic: -10.576657780341959
# p-value: 7.076922818587193e-19

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(widget_sales_diff,lags=30)
plt.show()

# %%
df_diff = pd.DataFrame({'widget_sales_diff':widget_sales_diff})

train = df_diff[:int(0.9*len(df_diff))]
test = df_diff[int(0.9*len(df_diff)):]

# %%
plt.plot(df['widget_sales'])

# %%
plt.plot(df_diff['widget_sales_diff'])

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
def rolling_forecast(df: pd.DataFrame, train_len: int, horizon: int, window: int, method: str) -> list:
    
    total_len = train_len + horizon
    
    if method == 'mean':
        pred_mean = []
        
        for i in range(train_len, total_len, window):
            mean = np.mean(df[:i].values)
            pred_mean.extend(mean for _ in range(window))

        return pred_mean

    elif method == 'last':
        pred_last_value = []
        
        for i in range(train_len, total_len, window):
            last_value = df[:i].iloc[-1].values[0]
            pred_last_value.extend(last_value for _ in range(window))
            
        return pred_last_value
    
    elif method == 'MA':
        pred_MA = []
        
        for i in range(train_len, total_len, window):
            model = SARIMAX(df[:i], order=(0,0,2))
            res = model.fit(disp=False)
            predictions = res.get_prediction(0, i + window - 1)
            oos_pred = predictions.predicted_mean.iloc[-window:]
            pred_MA.extend(oos_pred)
            
        return pred_MA

# %%
pred_df = test.copy()

TRAIN_LEN = len(train)
HORIZON = len(test)
WINDOW = 2

pred_df['pred_mean'] = rolling_forecast(df_diff,TRAIN_LEN,HORIZON,WINDOW,'mean')
pred_df['pred_last_value'] = rolling_forecast(df_diff,TRAIN_LEN,HORIZON,WINDOW,'last')
pred_df['pred_MA'] = rolling_forecast(df_diff,TRAIN_LEN,HORIZON,WINDOW,'MA')

pred_df.head()
# Out:
#      widget_sales_diff  pred_mean  pred_last_value   pred_MA2   pred_MA
# 449          -1.170131   0.034319        -1.803658  45.143491 -1.078833
# 450           0.580967   0.034319        -1.803658  12.420019 -0.273309
# 451          -0.144902   0.032861         0.580967  44.405939  0.781223
# 452          -0.096564   0.032861         0.580967  12.352963  0.234969
# 453          -0.372334   0.032183        -0.096564  44.245503  0.168994

# %%
fig, ax = plt.subplots()
ax.plot(pred_df['widget_sales_diff'],'b-', label='Actual')
ax.plot(pred_df['pred_mean'], 'r:', label='Mean')
ax.plot(pred_df['pred_last_value'], 'g:', label='Last')
ax.plot(pred_df['pred_MA'], 'r-', label='MA2')

ax.set_xlabel('Timesteps')
ax.set_ylabel('Value')

ax.legend(loc='best')


fig.autofmt_xdate()
plt.tight_layout()

# %%
from sklearn.metrics import mean_squared_error 
pred_mean = mean_squared_error(pred_df['widget_sales_diff'],pred_df['pred_mean'])
pred_last_value = mean_squared_error(pred_df['widget_sales_diff'],pred_df['pred_last_value'])
pred_ma = mean_squared_error(pred_df['widget_sales_diff'],pred_df['pred_MA'])

# %%
x=['Mean_value','Last Value','MA value']
y=[pred_mean,pred_last_value,pred_ma]
sns.barplot(x=x,y=y)
# Out:
# <Axes: >

# %%
df['pred_series_sales'] = pd.Series()
df['pred_series_sales'][450:] = df['widget_sales'].iloc[450]+pred_df['pred_MA'].cumsum()

# %%
plt.plot(df['widget_sales'])
plt.plot(df['pred_series_sales'].dropna())
plt.xticks(rotation=45)
plt.show()

# %%
from itertools import product
p = range(0,4,1)
q = range(0,4,1)
list(product(p,q))
# Out:
# [(0, 0),
#  (0, 1),
#  (0, 2),
#  (0, 3),
#  (1, 0),
#  (1, 1),
#  (1, 2),
#  (1, 3),
#  (2, 0),
#  (2, 1),
#  (2, 2),
#  (2, 3),
#  (3, 0),
#  (3, 1),
#  (3, 2),
#  (3, 3)]

# %% [markdown]
# # ARMA Model

# %%
from statsmodels.tsa.arima_process import ArmaProcess

# %%
np.random.seed(42)
ar1 = np.array([1,-0.33])
ma1 = np.array([1,0.9])
ARMA_1_1 = ArmaProcess(ar1,ma1).generate_sample(nsample=1000)

# %%
plt.plot(ARMA_1_1)

# %%
# Performing ADFuller test
from statsmodels.tsa.stattools import adfuller
adfuller_test = adfuller(ARMA_1_1)
print(f'ADF Statistic: {adfuller_test[0]}')
print(f'p-value: {adfuller_test[1]}')
# Out:
# ADF Statistic: -6.429878682042698
# p-value: 1.707846668009623e-08

# %%
# Plot ACF and PACF
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
plot_acf(ARMA_1_1)
plt.show()

# %%
plot_pacf(ARMA_1_1)
plt.show()

# %%
# Combination of P and Q values
from itertools import product
ps = range(0,4,1)
qs = range(0,4,1)
order_list = list(product(ps,qs))

# %%
# Function to fit all the unique ARMA(p,q) models
from typing import Union
from tqdm import tqdm_notebook
from statsmodels.tsa.statespace.sarimax import SARIMAX

def optimize_ARMA (endog:Union[pd.Series,list],order_list:list)-> pd.DataFrame:
    results = []
    for order in tqdm_notebook(order_list):
        try:
            model = SARIMAX(endog,order=(order[0],0,order[1]),
                            simple_differencing=False).fit(disp=False)
        except:
            continue
            
        aic=model.aic
        results.append([order,aic])
    result_df = pd.DataFrame(results)
    result_df.columns = ['(p,q)', 'AIC']
    
    # Sort in ascending order the list, lower AIC
    result_df.sort_values(by='AIC',ascending=True,inplace=True)
    return result_df

# %%
optimize_ARMA(ARMA_1_1,order_list)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
#      (p,q)          AIC
# 5   (1, 1)  2801.407785
# 9   (2, 1)  2802.906070
# 6   (1, 2)  2802.967762
# 3   (0, 3)  2803.666793
# 7   (1, 3)  2804.524027
# 13  (3, 1)  2804.588567
# 10  (2, 2)  2804.822282
# 15  (3, 3)  2805.972891
# 11  (2, 3)  2806.175380
# 14  (3, 2)  2806.894930
# 2   (0, 2)  2812.840730
# 1   (0, 1)  2891.869245
# 12  (3, 0)  2981.643911
# 8   (2, 0)  3042.627787
# 4   (1, 0)  3207.291261
# 0   (0, 0)  3780.418416

# %%
model = SARIMAX(ARMA_1_1,order=(1,0,1),simple_differencing=False)
model_fit = model.fit(disp=True)
residuals = model_fit.resid

from statsmodels.graphics.gofplots import qqplot
qqplot(residuals,line='45')
plt.show()

# %%
model_fit.plot_diagnostics(figsize=(10,8))
plt.show()

# %%
# Ljung box test 
from statsmodels.stats.diagnostic import acorr_ljungbox
lbvalue, pvalue = acorr_ljungbox(residuals,np.arange(1,11,1))
print(pvalue)
# Out:
# lb_pvalue

# %%
acorr_ljungbox(residuals,np.arange(1,11,1))
# Out:
#      lb_stat  lb_pvalue
# 1   0.030706   0.860897
# 2   0.528021   0.767966
# 3   0.540904   0.909817
# 4   2.079774   0.721089
# 5   2.271897   0.810385
# 6   2.896262   0.821750
# 7   2.900378   0.894063
# 8   4.418799   0.817501
# 9   4.787567   0.852419
# 10  5.246805   0.874093

# %% [markdown]
# The resulting list of p-values shows that each is above 0.05. Therefore, at each lag, the
# null hypothesis cannot be rejected, meaning that the residuals are independently distributed
# and uncorrelated.

# %%
df = pd.read_csv(r"C:\Users\91866\Downloads\bandwidth.csv")

# %%
plt.figure(figsize=(20,15))
df.plot()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
adfuller_test = adfuller(df)
print(f"ADF Statistic: {adfuller_test[0]}")
print(f"pvalue: {adfuller_test[1]}")
# Out:
# ADF Statistic: -0.8714653199451994
# pvalue: 0.7972240255014788

# %%
df_diff = np.diff(df['hourly_bandwidth'],n=1)

# %%
df_diff = pd.DataFrame({'bandwidth_diff':df_diff})

# %%
# Split the data into train and test
train = df_diff[:-168]
test = df_diff[-168:]

# %%
fig, (ax1,ax2) = plt.subplots(2,1,sharex=True,figsize=(10,8))
ax1.plot(df.hourly_bandwidth)
ax1.set_xlabel('Time')
ax1.set_ylabel('Hourly bandwidth')
ax1.axvspan(9831, 10000, alpha=0.2)
ax2.plot(df_diff.bandwidth_diff)
ax2.set_xlabel('Time')
ax2.set_ylabel('Hourly bandwidth (diff)')
ax2.axvspan(9830, 9999,  alpha=0.2)
plt.xticks(
np.arange(0, 10000, 730),
['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec', '2020', 'Feb'])
fig.autofmt_xdate()
plt.tight_layout()

# %%
result_df = optimize_ARMA(train['bandwidth_diff'],order_list)
result_df
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
#      (p,q)           AIC
# 14  (3, 2)  27991.063879
# 11  (2, 3)  27991.287509
# 10  (2, 2)  27991.603598
# 15  (3, 3)  27993.416924
# 7   (1, 3)  28003.349550
# 6   (1, 2)  28051.351401
# 13  (3, 1)  28071.155496
# 12  (3, 0)  28095.618186
# 9   (2, 1)  28097.250766
# 8   (2, 0)  28098.407664
# 5   (1, 1)  28172.510044
# 4   (1, 0)  28941.056983
# 3   (0, 3)  31355.802141
# 2   (0, 2)  33531.179284
# 1   (0, 1)  39402.269523
# 0   (0, 0)  49035.184224

# %%
model = SARIMAX(train['bandwidth_diff'],order=(3,0,2),simple_differencing=False)
model_fit = model.fit()
residuals = model_fit.resid

from statsmodels.graphics.gofplots import qqplot
qqplot(residuals)
plt.show()

# %%
model_fit.plot_diagnostics(figsize=(10,8))

# %%
from statsmodels.stats.diagnostic import acorr_ljungbox
acorr_ljungbox(residuals)
# Out:
#      lb_stat  lb_pvalue
# 1   0.000729   0.978461
# 2   0.015352   0.992353
# 3   0.044845   0.997508
# 4   0.081030   0.999201
# 5   0.311132   0.997428
# 6   0.359370   0.999154
# 7   0.448530   0.999614
# 8   1.350781   0.994917
# 9   1.371062   0.997995
# 10  1.871109   0.997236

# %%
def rolling_forecast(df: pd.DataFrame, train_len: int, horizon: int, window: int, method: str) -> list:
    
    total_len = train_len + horizon
    
    if method == 'mean':
        pred_mean = []
        
        for i in range(train_len, total_len, window):
            mean = np.mean(df[:i].values)
            pred_mean.extend(mean for _ in range(window))

        return pred_mean

    elif method == 'last':
        pred_last_value = []
        
        for i in range(train_len, total_len, window):
            last_value = df[:i].iloc[-1].values[0]
            pred_last_value.extend(last_value for _ in range(window))
            
        return pred_last_value
    
    elif method == 'ARMA':
        pred_ARMA = []
        
        for i in range(train_len, total_len, window):
            model = SARIMAX(df[:i], order=(3,0,2))
            res = model.fit(disp=False)
            predictions = res.get_prediction(0, i + window - 1)
            oos_pred = predictions.predicted_mean.iloc[-window:]
            pred_ARMA.extend(oos_pred)
            
        return pred_ARMA

# %%
pred_df = test.copy()

TRAIN_LEN = len(train)
HORIZON = len(test)
WINDOW = 2

pred_df['pred_mean'] = rolling_forecast(df_diff,TRAIN_LEN,HORIZON,WINDOW,'mean')
pred_df['pred_last_value'] = rolling_forecast(df_diff,TRAIN_LEN,HORIZON,WINDOW,'last')
pred_df['pred_ARMA'] = rolling_forecast(df_diff,TRAIN_LEN,HORIZON,WINDOW,'ARMA')

pred_df.head()
# Out:
#       bandwidth_diff  pred_mean  pred_last_value  pred_ARMA
# 9831       -5.943995  -0.028214        -5.791207  -5.453470
# 9832       -5.865194  -0.028214        -5.791207  -4.882322
# 9833       -3.197066  -0.029410        -5.865194  -5.347632
# 9834       -1.090197  -0.029410        -5.865194  -4.773876
# 9835        0.665291  -0.029840        -1.090197  -0.407950

# %%
fig, ax = plt.subplots()
ax.plot(df_diff['bandwidth_diff'])
ax.plot(pred_df['bandwidth_diff'], 'b-', label='actual')
ax.plot(pred_df['pred_mean'], 'g:', label='mean')
ax.plot(pred_df['pred_last_value'], 'r-.', label='last')
ax.plot(pred_df['pred_ARMA'], 'k--', label='ARMA(2,2)')
ax.legend(loc=2)
ax.set_xlabel('Time')
ax.set_ylabel('Hourly bandwidth (diff)')
ax.axvspan(9830, 9999, color='#808080', alpha=0.2)
ax.set_xlim(9800, 9999)
plt.xticks(
[9802, 9850, 9898, 9946, 9994],
['2020-02-13', '2020-02-15', '2020-02-17', '2020-02-19', '2020-02-21'])
fig.autofmt_xdate()
plt.tight_layout()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
mse_mean = mean_squared_error(pred_df['bandwidth_diff'],pred_df['pred_mean'])
mse_last = mean_squared_error(pred_df['bandwidth_diff'],pred_df['pred_last_value'])
mse_ARMA = mean_squared_error(pred_df['bandwidth_diff'],pred_df['pred_ARMA'])
print(mse_mean,mse_last,mse_ARMA)
# Out:
# 6.306526957989325 2.2297582947733656 1.7728168790598278

# %%
df['pred_bandwidth'] = pd.Series()
df['pred_bandwidth'][9832:] = df['hourly_bandwidth'].iloc[9832] + pred_df['pred_ARMA'].cumsum()

# %%
fig, ax = plt.subplots()
ax.plot(df['hourly_bandwidth'])
ax.plot(df['hourly_bandwidth'], 'b-', label='actual')
ax.plot(df['pred_bandwidth'], 'k--', label='ARMA(2,2)')
ax.legend(loc=2)
ax.set_xlabel('Time')
ax.set_ylabel('Hourly bandwith usage (MBps)')
ax.axvspan(9831, 10000, color='#808080', alpha=0.2)
ax.set_xlim(9800, 9999)
plt.xticks(
[9802, 9850, 9898, 9946, 9994],
['2020-02-13', '2020-02-15', '2020-02-17', '2020-02-19', '2020-02-21'])
fig.autofmt_xdate()
plt.tight_layout()

# %%
df.iloc[9000:].plot()
# Out:
# <Axes: >

# %%
# MAE for evaluation of the model, evaluation in simpler terms
from sklearn.metrics import mean_squared_error, mean_absolute_error
mae_mean = mean_absolute_error(pred_df['bandwidth_diff'],pred_df['pred_mean'])
mae_last = mean_absolute_error(pred_df['bandwidth_diff'],pred_df['pred_last_value'])
mae_ARMA = mean_absolute_error(pred_df['bandwidth_diff'],pred_df['pred_ARMA'])
y = [mae_ARMA,mae_last,mae_mean]
x = ['ARMA','Last values','Mean']
sns.barplot(x=x,y=y)
# Out:
# <Axes: >

# %% [markdown]
# # ARIMA

# %%
# load the dataset
df = pd.read_csv(r"C:/Users/91866/Downloads/jj.csv",index_col='date')

# %%
df.plot()
# Out:
# <Axes: xlabel='date'>

# %%
from statsmodels.tsa.stattools import adfuller
adfuller_test = adfuller(df)
print(f'ADF Statistics: {adfuller_test[0]}')
print(f'p-value: {adfuller_test[1]}')
# Out:
# ADF Statistics: 2.7420165734574735
# p-value: 1.0

# %%
eps_diff = np.diff(df['data'],n=1)
adfuller_test = adfuller(eps_diff)
print(f'ADF Statistics: {adfuller_test[0]}')
print(f'p-value: {adfuller_test[1]}')
# Out:
# ADF Statistics: -0.40740976363804116
# p-value: 0.9088542416911313

# %%
eps_diff2 = np.diff(eps_diff,n=1)
adfuller_test = adfuller(eps_diff2)
print(f'ADF Statistics: {adfuller_test[0]}')
print(f'p-value: {adfuller_test[1]}')
# Out:
# ADF Statistics: -3.585162874793187
# p-value: 0.006051099869603033

# %%
plt.plot(eps_diff,label='1st diff')
plt.plot(eps_diff2,label='2nd diff')
plt.legend()

# %%
from typing import Union
from tqdm import tqdm_notebook
from statsmodels.tsa.statespace.sarimax import SARIMAX

def optimize_ARIMA(endog:Union[pd.Series,list],order_list:list,d:int)-> pd.DataFrame:
    results =[]
    for order in tqdm_notebook(order_list):
        try:
            model = SARIMAX(endog, order=(order[0], d, order[1]),
                            simple_differencing=False).fit(disp=False)
        except:
            continue
            
        aic = model.aic
        results.append([order,aic])
    result_df = pd.DataFrame(results)
    result_df.columns = ['(p,q)', 'AIC']
    #Sort in ascending order, lower AIC is better
    result_df = result_df.sort_values(by='AIC',
                                      ascending=True).reset_index(drop=True)
    return result_df

# %%
from itertools import product
ps = range(0,4,1)
qs = range(0,4,1)
order_list = list(product(ps,qs))

# %%
# Splitting the data into train and test
train = df.data[:-4]
result_df = optimize_ARIMA(train,order_list,2)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]

# %%
result_df
# Out:
#      (p,q)         AIC
# 0   (3, 3)  115.270330
# 1   (3, 1)  115.624980
# 2   (3, 2)  115.672006
# 3   (3, 0)  154.430620
# 4   (0, 3)  194.654716
# 5   (0, 2)  209.274692
# 6   (2, 3)  220.666872
# 7   (1, 3)  228.267766
# 8   (1, 2)  228.935813
# 9   (2, 2)  229.974701
# 10  (2, 1)  234.501112
# 11  (1, 1)  236.117237
# 12  (0, 1)  252.601006
# 13  (2, 0)  280.299907
# 14  (1, 0)  280.389386
# 15  (0, 0)  320.324435

# %%
model = SARIMAX(train,order=(3,2,3),simple_differencing=False)
model_fit = model.fit()

# %%
model_fit.plot_diagnostics(figsize=(10,8))
plt.show()

# %%
from statsmodels.stats.diagnostic import acorr_ljungbox
residuals = model_fit.resid.reset_index()
residuals
# Out:
#           date         0
# 0   1960-01-01  0.710000
# 1   1960-04-01 -0.434997
# 2   1960-07-02  0.299985
# 3   1960-10-01 -0.364681
# 4   1961-01-01  0.001885
# ..         ...       ...
# 75  1978-10-01 -1.682424
# 76  1979-01-01  0.566774
# 77  1979-04-02 -0.195892
# 78  1979-07-02  1.143106
# 79  1979-10-01 -0.674505
#
# [80 rows x 2 columns]

# %%
test = df.iloc[-4:]
test['naive_seasonal'] = df['data'].iloc[76:80].values

# %%
ARIMA_pred = model_fit.get_prediction(80,83).predicted_mean
ARIMA_pred.index = test.index

# %%
test['ARIMA_pred'] = ARIMA_pred

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

fig, ax = plt.subplots()

# Plot actual data
ax.plot(df['data'].iloc[-20:], 'b-', label='Actual')

# Plot naive seasonal forecast
ax.plot(test['naive_seasonal'], 'k--', label='Naive Seasonal')

# Plot ARIMA forecast
ax.plot(test['ARIMA_pred'], 'g--', label='ARIMA(3,2,3)')

# Legend and labels
ax.legend(loc='upper left')
ax.set_xlabel('Time')
ax.set_ylabel('Earnings per share (USD)')

# Format x-axis dates
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))  # Adjust date format as needed

# Rotate and align x-axis labels
fig.autofmt_xdate()

# Ensure tight layout
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# # SARIMAX

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv(r"C:\Users\91866\Downloads\airline_passengers.csv")

# %%
df.set_index('Month',inplace=True)

# %%
df = df.iloc[:-1]

# %%
df.plot()
plt.xticks(rotation=45)
plt.show()

# %%
df.index = pd.to_datetime(df.index)

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decompose = seasonal_decompose(df['Thousands of Passengers'],period=12)
decompose.plot()
plt.show()

# %%
df
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                    112.0
# 1949-02-01                    118.0
# 1949-03-01                    132.0
# 1949-04-01                    129.0
# 1949-05-01                    121.0
# ...                             ...
# 1960-08-01                    606.0
# 1960-09-01                    508.0
# 1960-10-01                    461.0
# 1960-11-01                    390.0
# 1960-12-01                    432.0
#
# [144 rows x 1 columns]

# %%
from statsmodels.tsa.stattools import adfuller
adfuller_test = adfuller(df['Thousands of Passengers'])
print(f"ADF Statistics: {adfuller_test[0]}")
print(f"ADF Statistics: {adfuller_test[1]}")
# Out:
# ADF Statistics: 0.8153688792060482
# ADF Statistics: 0.991880243437641

# %%
df_diff = np.diff(df['Thousands of Passengers'],n=1)
adfuller_test = adfuller(df_diff)
print(f"ADF Statistics: {adfuller_test[0]}")
print(f"ADF Statistics: {adfuller_test[1]}")
# Out:
# ADF Statistics: -2.8292668241699994
# ADF Statistics: 0.0542132902838255

# %%
df_diff2 = np.diff(df_diff,n=1)
adfuller_test = adfuller(df_diff2)
print(f"ADF Statistics: {adfuller_test[0]}")
print(f"ADF Statistics: {adfuller_test[1]}")
# Out:
# ADF Statistics: -16.384231542468505
# ADF Statistics: 2.7328918500142407e-29

# %%
from itertools import product
ps = range(0,13,1)
qs = range(0,13,1)
Ps = [0]
Qs = [0]
d = 2
D = 0
S = 12
ARIMA_order_list = list(product(ps,qs,Ps,Qs))

# %%
train = df[:-12]
test = df[-12:]
print(len(train))
print(len(test))
# Out:
# 132
# 12

# %%
from typing import Union
from tqdm import tqdm_notebook
from statsmodels.tsa.statespace.sarimax import SARIMAX
import warnings
warnings.filterwarnings('ignore')
def optimize_SARIMA(endog:Union[pd.Series,list],order_list:list, d:int, D:int, s:int)-> pd.DataFrame:
    results = []
    for order in tqdm_notebook(order_list):
        try:
            model = SARIMAX(endog,
                           order=(order[0],d,order[1]),
                            seasonal_order=(order[2],D,order[3],s),
                            simple_differencing=False).fit(disp=False)
        except:
            continue
        aic = model.aic
        results.append([order,aic])
    result_df = pd.DataFrame(results)
    result_df.columns = ['p,q,P,Q','AIC']
    #Sort in ascending order, lower AIC is better
    result_df = result_df.sort_values(by='AIC',ascending=True).reset_index(drop=True)
    return result_df

# %%
results_df = optimize_SARIMA(train,ARIMA_order_list,d,D,S)
results_df
# Out:
#   0%|          | 0/169 [00:00<?, ?it/s]
#            p,q,P,Q          AIC
# 0    (11, 3, 0, 0)  1016.901297
# 1    (11, 4, 0, 0)  1019.013021
# 2    (11, 5, 0, 0)  1020.417057
# 3    (12, 0, 0, 0)  1020.528589
# 4    (11, 1, 0, 0)  1021.018051
# ..             ...          ...
# 164   (5, 0, 0, 0)  1281.732157
# 165   (3, 0, 0, 0)  1300.282335
# 166   (2, 0, 0, 0)  1302.913196
# 167   (1, 0, 0, 0)  1308.152194
# 168   (0, 0, 0, 0)  1311.919269
#
# [169 rows x 2 columns]

# %%
ARIMA_model = SARIMAX(endog=train['Thousands of Passengers'],order=(11,2,3),simple_differencing=(False))
ARIMA_model_fit = ARIMA_model.fit(disp=True)
ARIMA_model_fit.plot_diagnostics(figsize=(10,8))
plt.show()

# %%
test['naive_seasonal'] = train['Thousands of Passengers'].iloc[-12:].values

# %%
ARIMA_pred = ARIMA_model_fit.get_prediction(132,143).predicted_mean

# %%
test['ARIMA Pred'] = ARIMA_pred

# %%
# Seasonal- Stationary test
adfuller_test = adfuller(df['Thousands of Passengers'])
print(f"ADF Statistics: {adfuller_test[0]}")
print(f"ADF Statistics: {adfuller_test[1]}")
# Out:
# ADF Statistics: 0.8153688792060482
# ADF Statistics: 0.991880243437641

# %%
df_diff = np.diff(df['Thousands of Passengers'],n=1)
adfuller_test = adfuller(df_diff)
print(f"ADF Statistics: {adfuller_test[0]}")
print(f"ADF Statistics: {adfuller_test[1]}")
# Out:
# ADF Statistics: -2.8292668241699994
# ADF Statistics: 0.0542132902838255

# %%
df_diff2 = np.diff(df_diff,n=12)
adfuller_test = adfuller(df_diff2)
print(f"ADF Statistics: {adfuller_test[0]}")
print(f"ADF Statistics: {adfuller_test[1]}")
# Out:
# ADF Statistics: -17.62486236018866
# ADF Statistics: 3.823046855895306e-30

# %%
ps = range(0,4,1)
qs = range(0,4,1)
Ps = range(0,4,1)
Qs = range(0,4,1)

SARIMA_order_list = list(product(ps,qs,Ps,Qs))

d=1
D=1
s=12

SARIMA_result = optimize_SARIMA(train,SARIMA_order_list,d,D,s)
SARIMA_result
# Out:
#   0%|          | 0/256 [00:00<?, ?it/s]
#           p,q,P,Q         AIC
# 0    (2, 1, 1, 2)  892.239168
# 1    (2, 1, 2, 1)  893.788113
# 2    (2, 1, 1, 3)  894.123379
# 3    (1, 0, 1, 2)  894.285333
# 4    (2, 1, 2, 3)  894.840889
# ..            ...         ...
# 251  (0, 0, 2, 0)  906.940147
# 252  (3, 2, 0, 3)  907.181875
# 253  (0, 0, 3, 2)  907.483824
# 254  (0, 0, 3, 0)  908.742583
# 255  (0, 0, 0, 3)  908.781405
#
# [256 rows x 2 columns]

# %%
SARIMA_model = SARIMAX(endog=train['Thousands of Passengers'],order=(2,1,1),seasonal_order=(1,1,2,12),simple_differencing=(False))
SARIMA_model_fit = SARIMA_model.fit(disp=True)
SARIMA_model_fit.plot_diagnostics(figsize=(10,8))
plt.show()
