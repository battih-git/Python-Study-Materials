# %%
import pandas as pd
import pandas_datareader as pdr
from datetime import datetime

# %%
df = pdr.get_data_stooq('TSLA')

# %%
df
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 2024-02-16  202.0600  203.1700  197.4000  199.9500  111346705
# 2024-02-15  189.1600  200.8800  188.8595  200.4500  120831762
# 2024-02-14  185.3000  188.8900  183.3500  188.7100   81202987
# 2024-02-13  183.9900  187.2600  182.1087  184.0200   86759478
# 2024-02-12  192.1100  194.7300  187.2800  188.1300   95498597
# ...              ...       ...       ...       ...        ...
# 2019-02-25   19.8607   20.1937   19.8000   19.9180   99397830
# 2019-02-22   19.6327   19.7667   19.4733   19.6473   86108370
# 2019-02-21   20.1207   20.2160   19.3667   19.4153  133637730
# 2019-02-20   20.2940   20.4200   19.9333   20.1707  107131755
# 2019-02-19   20.4373   20.7697   20.3647   20.3760   62526645
#
# [1259 rows x 5 columns]

# %%
# Simple Moving average - Window size 20
df_sma = df['Open'].rolling(20).mean()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(12,4))
df_sma.plot(legend=True,label="Moving average")
df['Open'].plot(legend=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda\lib\site-packages\pandas\core\indexes\base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File ~\anaconda\lib\site-packages\pandas\_libs\index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda\lib\site-packages\pandas\_libs\index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Open'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Cumulative moving average
plt.figure(figsize=(12,4))
df['Open'].expanding().mean().plot(legend = True,label = 'Cumulative Moving average')
df['Open'].plot(legend=True)
# Out:
# <Axes: xlabel='Date'>

# %%
# Exponential Moving Average
df['Open'].ewm(alpha=0.05,adjust=False).mean().plot(legend=True,label='EWM')
df['Open'].plot(legend=True)
# Out:
# <Axes: xlabel='Date'>

# %%
df.to_clipboard()

# %%
# Cumulative moving average
plt.figure(figsize=(12,4))
df['Open'].expanding().mean().plot(legend = True,label = 'Cumulative Moving average')
df['Open'].plot(legend=True)

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\91866\Downloads\boston.csv")

# %%
df.plot.hexbin(x='DIS',y='AGE',sharex=False,gridsize=30)
# Out:
# <Axes: xlabel='DIS', ylabel='AGE'>

# %%
sns.kdeplot(df,x='DIS',y='AGE')
# Out:
# <Axes: xlabel='DIS', ylabel='AGE'>

# %%
sns.scatterplot(df,x='DIS',y='AGE')
# Out:
# <Axes: xlabel='DIS', ylabel='AGE'>

# %%
plt.figure(figsize=(12,12 ))
import seaborn as sns
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sample = df.sample(30)
sample['MEDV'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sample = df.sample(50)
sample['MEDV'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sample = df.sample(100)
sample['MEDV'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sample = df.sample(5)
sample['MEDV'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['MEDV'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
len(df)
# Out:
# 506

# %%
import numpy as np
my_list = []
for i in range(50):
    n = np.random.randint(10,30)
    sample = df['MEDV'].sample(n)
    my_list.append(sample.mean())

# %%
sns.histplot(my_list)
# Out:
# <Axes: ylabel='Count'>

# %%
np.mean(my_list)
# Out:
# 22.36879522466277

# %%
df['MEDV'].mean()
# Out:
# 22.532806324110698

# %%
np.std(my_list)
# Out:
# 1.9767864233424466

# %%
len(my_list)
# Out:
# 50

# %%
2/np.sqrt(100)
# Out:
# 0.2

# %%
from scipy.stats import probplot
from scipy import stats

# %%
fig,ax = plt.subplots(figsize=(4,4))
norm_sample = stats.norm.rvs(size=500)
probplot(norm_sample,plot=ax)
plt.show()

# %%
normal = np.random.normal(size=1000)

# %%
fig,ax = plt.subplots(figsize=(4,4))
probplot(normal,plot=ax)
plt.show()

# %%
sns.histplot(normal)
# Out:
# <Axes: ylabel='Count'>

# %%
stats.binomtest(k=50,n=200,p=0.5)
# Out:
# BinomTestResult(k=50, n=200, alternative='two-sided', statistic=0.25, pvalue=8.393020875604775e-13)

# %%
stats.binom_test(x=0,n=200,p=0.02)
# Out:
# C:\Users\91866\AppData\Local\Temp\ipykernel_10212\2261021318.py:1: DeprecationWarning: 'binom_test' is deprecated in favour of 'binomtest' from version 1.7.0 and will be removed in Scipy 1.12.0.
#   stats.binom_test(x=0,n=200,p=0.02)
# 0.0377628225899724

# %%
stats.binom.pmf(k=0,n=1000,p=0.5)
# Out:
# 9.332636185032189e-302

# %%
stats.binom.pmf(k=200,n=1000,p=0.5)
# Out:
# 6.1755505427400564e-86

# %%
poisson = stats.poisson.rvs(2,size=100)
poisson
# Out:
# array([1, 3, 3, 0, 1, 2, 0, 1, 2, 4, 1, 5, 1, 3, 3, 2, 5, 3, 1, 3, 2, 1,
#        2, 2, 3, 2, 4, 1, 3, 2, 1, 5, 2, 1, 0, 3, 2, 2, 2, 1, 1, 1, 1, 1,
#        1, 2, 3, 1, 2, 1, 1, 2, 4, 4, 3, 2, 1, 2, 2, 1, 1, 1, 1, 2, 2, 4,
#        1, 4, 5, 0, 4, 3, 4, 2, 3, 2, 2, 1, 3, 3, 4, 1, 1, 1, 4, 2, 1, 1,
#        1, 0, 1, 1, 4, 2, 2, 2, 4, 3, 1, 1], dtype=int64)

# %%
plt.plot(poisson)

# %%
sns.kdeplot(poisson)
# Out:
# <Axes: ylabel='Density'>

# %%
expo = stats.expon.rvs(0.02,size=100)

# %%
expo
# Out:
# array([0.10006546, 0.52415777, 0.16309948, 1.38971424, 1.32227069,
#        0.38139467, 0.71314539, 1.43310044, 0.08483431, 2.64738627,
#        1.2609322 , 0.29186615, 0.355111  , 2.65541872, 2.25725834,
#        0.45275675, 0.40807059, 1.01433783, 1.1232791 , 0.35886388,
#        1.08547311, 0.06789639, 0.66600982, 0.42331864, 0.79432682,
#        0.04022865, 1.02872525, 0.32628546, 0.43293866, 0.91711768,
#        0.4591209 , 0.52817029, 0.43322498, 0.07011764, 0.36714984,
#        0.28843083, 1.51909216, 1.70450122, 0.40253245, 0.70000726,
#        0.45620121, 0.76911662, 5.51985049, 1.09074972, 0.16223984,
#        0.17601431, 0.76743488, 0.03003068, 1.41823542, 1.42291727,
#        1.8006502 , 0.90144129, 0.35268883, 0.53732632, 2.7473365 ,
#        0.92776564, 0.18869391, 0.58517097, 0.45090696, 3.0675197 ,
#        4.089229  , 0.78428866, 0.94089429, 0.86265668, 0.79088334,
#        0.36053573, 1.54670415, 0.87316206, 0.90701153, 0.31152775,
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[158], line 1
# ----> 1 sns.kdeplot(expo,pd.date_range('20210101',periods=100))
#
# TypeError: kdeplot() takes from 0 to 1 positional arguments but 2 were given
